# %% [markdown]
# # Inteligência Artificial e Aprendizado de Máquina
#
# **Prof. Dr. Francisco de Assis Boldt**
# **Pós-graduação em Desenvolvimento de Aplicações Inteligentes**
# **Inteligência Artificial e Aprendizado de Máquina — Atividade 01 - Regressão**

# %% [markdown]
# **Nome:** Otávio Lube dos Santos
# **Matrícula:** 20231DEVAI0157

# %% [markdown]
# ## Regressão
#
# A função load_boston utilizada para carregar o Boston dataset nos vídeos não está mais disponível no scikit-learn.
#
# Implemente as atividades dos vídeos em um Jupyter notebook com outro dataset de regressão. Salve esse notebook em um repositório público de sua posse no GitHub. A entrega desta tarefa é um link para o seu notebook.
#
# **Solução:** Utilizar o dataset load_diabetes do SciKit Learning para implementar os algoritmos de regressão dos vídeos

# %%
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
diabetes.keys()
print(diabetes.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
#     - s6      glu, blood sugar level
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# Bradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.
# (https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)

# %%
X, y = diabetes.data, diabetes.target
X.shape, y.shape
# Out:
# ((442, 10), (442,))

# %%
import matplotlib.pylab as plt
for i in range(X.shape[1]):  # Iterar sobre todas as colunas
    print(f"Plotando coluna {i}")
    plt.scatter(X[:, i], y)
    plt.xlabel(f"Feature {i}")
    plt.ylabel("Target")
    plt.show()
# Out:
# Plotando coluna 0
# Plotando coluna 1
# Plotando coluna 2
# Plotando coluna 3
# Plotando coluna 4
# Plotando coluna 5
# Plotando coluna 6
# Plotando coluna 7
# Plotando coluna 8
# Plotando coluna 9

# %%
X9 = X[:,9:10]
plt.scatter(X9, y)

plt.plot()
# Out:
# []

# %%
def modelo_linear(X, a, b):
    y = a*X + b 
    return y

ypred = modelo_linear(X9, 1500, 120)
plt.scatter(X9, y)
plt.plot(X9, ypred, 'r')
plt.show()

# %%
import numpy as np

def mae(y, ypred):  
    yDiff = ypred - y
    yAbs = np.abs(yDiff)
    
    mae = np.mean(yAbs)
    return mae

ypred = modelo_linear(X9, -1, 40) 
resultado_mae = mae(y, ypred)
print(f"Mean Absolute Error (MAE): {resultado_mae}")
# Out:
# Mean Absolute Error (MAE): 112.26478968454069

# %%
def mse(y, ypred):
       # Calcular o erro ao quadrado
    squared_diff = (ypred - y) ** 2
    
    # Calcular o MSE como a média dos erros ao quadrado
    mse = np.mean(squared_diff)
    return mse

# Exemplo de uso
ypred = modelo_linear(X9, -1, 40)  # Certifique-se que esta função retorna algo compatível
resultado_mse = mse(y, ypred)
print(f"Mean Squared Error (MSE): {resultado_mse}")
# Out:
# Mean Squared Error (MSE): 18503.805429864253

# %%
def rmse(y, ypred):
    squared_diff = (ypred - y) ** 2
    
    mse = np.mean(squared_diff)
    
    rmse = np.sqrt(mse)
    return rmse

# Exemplo de uso
ypred = modelo_linear(X9, -1, 40)  # Certifique-se que esta função retorna algo compatível
resultado_rmse = rmse(y, ypred)
print(f"Root Mean Squared Error (RMSE): {resultado_rmse}")
# Out:
# Root Mean Squared Error (RMSE): 136.02869340644367

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

def rmse(y, ypred):
    mse = mean_squared_error(y, ypred)
    return sqrt(mse)
ypred = modelo_linear(X9, -1, 40)
rmse(y, ypred)
# Out:
# 136.0389919952365

# %%
class regressao_linear():
    def __init__(self):
        self.a = 0
        self.b = 0
    def fit(self, X, y):
        for _ in range(500):
            ypred = self.predict(X)
            erro = ypred - y.reshape(-1,1)
            ajusteB = (sum(erro)/len(erro))
            self.b = self.b - 0.1*ajusteB[0]
            
            ajusteA = sum([erro[i]*X[i] for i in range(X.shape[0])])/sum(X)
            self.a = self.a - 0.1*ajusteA[0]
            
    def predict(self, X):
        y = self.a*X + self.b
        return y
    
plt.scatter(X9, y)
modelo = regressao_linear()
ypred=modelo.predict(X9)
print(rmse(y, ypred))
plt.plot(X9, ypred, 'r')

modelo.fit(X9, y)

ypred=modelo.predict(X9)
print(y)
print(ypred)
print(rmse(y, ypred))
plt.plot(X9, ypred, 'g')

plt.show()
modelo.a, modelo.b
# Out:
# 170.51240981363347
# /var/folders/0v/yq16f3tn4rj4w6jh3tnsp47m0000gp/T/ipykernel_73420/4121324649.py:12: RuntimeWarning: overflow encountered in divide
#   ajusteA = sum([erro[i]*X[i] for i in range(X.shape[0])])/sum(X)
# /var/folders/0v/yq16f3tn4rj4w6jh3tnsp47m0000gp/T/ipykernel_73420/4121324649.py:9: RuntimeWarning: invalid value encountered in add
#   ajusteB = (sum(erro)/len(erro))
# /var/folders/0v/yq16f3tn4rj4w6jh3tnsp47m0000gp/T/ipykernel_73420/4121324649.py:13: RuntimeWarning: invalid value encountered in scalar subtract
#   self.a = self.a - 0.1*ajusteA[0]
# [151.  75. 141. 206. 135.  97. 138.  63. 110. 310. 101.  69. 179. 185.
#  118. 171. 166. 144.  97. 168.  68.  49.  68. 245. 184. 202. 137.  85.
#  131. 283. 129.  59. 341.  87.  65. 102. 265. 276. 252.  90. 100.  55.
#   61.  92. 259.  53. 190. 142.  75. 142. 155. 225.  59. 104. 182. 128.
#   52.  37. 170. 170.  61. 144.  52. 128.  71. 163. 150.  97. 160. 178.
#   48. 270. 202. 111.  85.  42. 170. 200. 252. 113. 143.  51.  52. 210.
#   65. 141.  55. 134.  42. 111.  98. 164.  48.  96.  90. 162. 150. 279.
#   92.  83. 128. 102. 302. 198.  95.  53. 134. 144. 232.  81. 104.  59.
#  246. 297. 258. 229. 275. 281. 179. 200. 200. 173. 180.  84. 121. 161.
#   99. 109. 115. 268. 274. 158. 107.  83. 103. 272.  85. 280. 336. 281.
#  118. 317. 235.  60. 174. 259. 178. 128.  96. 126. 288.  88. 292.  71.
#  197. 186.  25.  84.  96. 195.  53. 217. 172. 131. 214.  59.  70. 220.
#  268. 152.  47.  74. 295. 101. 151. 127. 237. 225.  81. 151. 107.  64.
#  138. 185. 265. 101. 137. 143. 141.  79. 292. 178.  91. 116.  86. 122.
#   72. 129. 142.  90. 158.  39. 196. 222. 277.  99. 196. 202. 155.  77.
#  191.  70.  73.  49.  65. 263. 248. 296. 214. 185.  78.  93. 252. 150.
#   77. 208.  77. 108. 160.  53. 220. 154. 259.  90. 246. 124.  67.  72.
#  257. 262. 275. 177.  71.  47. 187. 125.  78.  51. 258. 215. 303. 243.
#   91. 150. 310. 153. 346.  63.  89.  50.  39. 103. 308. 116. 145.  74.
#   45. 115. 264.  87. 202. 127. 182. 241.  66.  94. 283.  64. 102. 200.
#  265.  94. 230. 181. 156. 233.  60. 219.  80.  68. 332. 248.  84. 200.
#   55.  85.  89.  31. 129.  83. 275.  65. 198. 236. 253. 124.  44. 172.
#  114. 142. 109. 180. 144. 163. 147.  97. 220. 190. 109. 191. 122. 230.
#  242. 248. 249. 192. 131. 237.  78. 135. 244. 199. 270. 164.  72.  96.
#  306.  91. 214.  95. 216. 263. 178. 113. 200. 139. 139.  88. 148.  88.
#  243.  71.  77. 109. 272.  60.  54. 221.  90. 311. 281. 182. 321.  58.
#  262. 206. 233. 242. 123. 167.  63. 197.  71. 168. 140. 217. 121. 235.
#  245.  40.  52. 104. 132.  88.  69. 219.  72. 201. 110.  51. 277.  63.
#  118.  69. 273. 258.  43. 198. 242. 232. 175.  93. 168. 275. 293. 281.
#   72. 140. 189. 181. 209. 136. 261. 113. 131. 174. 257.  55.  84.  42.
#  146. 212. 233.  91. 111. 152. 120.  67. 310.  94. 183.  66. 173.  72.
#   49.  64.  48. 178. 104. 132. 220.  57.]
# [[nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]]
# nan
# (np.float64(nan), np.float64(nan))

# %% [markdown]
# ## Com notação vetorial

# %%
class regressao_linear():
    def __init__(self):
        self.w = np.zeros((2,1))
    @staticmethod
    def addBias(X):
        bias = np.ones((X.shape[0], 1))
        X_b = np.concatenate((bias,X), axis=1)
        return X_b
    def fit(self, X, y):
        X_b = self.addBias(X)
        for _ in range(500):
            ypred = self.predict(X)
            erro = ypred - y.reshape(-1,1)
            ajuste = X_b.T.dot(erro)/sum(X_b).reshape(-1,1)
            self.w = self.w - 0.1*ajuste
            
    def predict(self, X):
        X_b = self.addBias(X)
        y = X_b.dot(self.w)
        return y

# %%
plt.scatter(X9, y)
modelo = regressao_linear()
ypred=modelo.predict(X9)
print(rmse(y, ypred))
plt.plot(X9, ypred, 'r')

modelo.fit(X9, y)

ypred=modelo.predict(X9)
print(rmse(y, ypred))
plt.plot(X9, ypred, 'g')

plt.show()
modelo.w
# Out:
# 170.51240981363347
# nan
# /var/folders/0v/yq16f3tn4rj4w6jh3tnsp47m0000gp/T/ipykernel_73420/830748154.py:14: RuntimeWarning: overflow encountered in divide
#   ajuste = X_b.T.dot(erro)/sum(X_b).reshape(-1,1)
# /var/folders/0v/yq16f3tn4rj4w6jh3tnsp47m0000gp/T/ipykernel_73420/830748154.py:15: RuntimeWarning: invalid value encountered in subtract
#   self.w = self.w - 0.1*ajuste
# array([[nan],
#        [nan]])

# %% [markdown]
# ## Análise do Erro

# %%
import numpy as np
w0 = np.linspace(33,36,30)
w1 = np.linspace(-1,-0.8,30)

def z_function(W0, W1):
    modelo = regressao_linear()
    Erro = np.empty(W0.shape)
    for j in range(Erro.shape[0]):
        for k in range(Erro.shape[1]):
            modelo.w[0] = W0[j][k]
            modelo.w[1] = W1[j][k]
            ypred = modelo.predict(X9)
            mse = mean_squared_error(y, ypred)
            Erro[j][k] = mse
    return Erro
        

ax = plt.axes(projection="3d")
W0, W1 = np.meshgrid(w0, w1)
Erro = z_function(W0, W1)

ax.plot_wireframe(W0, W1, Erro)
ax.plot_surface(W0, W1, Erro, rstride=1, cstride=1, alpha=0.75, cmap='coolwarm', edgecolor='none')

plt.show()

# %%
plt.ylabel("Erro")
plt.xlabel("W0")
i = 8
plt.plot(W0[i,:],Erro[i,:])
plt.show()

# %%
plt.ylabel("Erro")
plt.xlabel("W1")
i = 8
plt.plot(W1[:,i],Erro[:,i])
plt.show()

# %% [markdown]
# ## Alterando o modelo de predição

# %%
class regressao_linear():
    def __init__(self):
        self.w = np.zeros((2,1))
        self.wh = []
    @staticmethod
    def addBias(X):
        bias = np.ones((X.shape[0], 1))
        X_b = np.concatenate((bias,X), axis=1)
        return X_b
    def fit(self, X, y):
        X_b = self.addBias(X)
        for _ in range(20):
            ypred = self.predict(X)
            erro = ypred - y.reshape(-1,1)
            ajuste = X_b.T.dot(erro)/sum(X_b).reshape(-1,1)
            self.w = self.w - 0.1*ajuste
            ypred = self.predict(X)
            mse = mean_squared_error(y, ypred)
            self.wh.append([self.w[0,0], self.w[1,0], mse])
            
    def predict(self, X):
        X_b = self.addBias(X)
        y = X_b.dot(self.w)
        return y

# %%
w0 = np.linspace(0,16,30)
w1 = np.linspace(0,2,30)

def z_function(W0, W1):
    modelo = regressao_linear()
    Erro = np.empty(W0.shape)
    for j in range(Erro.shape[0]):
        for k in range(Erro.shape[1]):
            modelo.w[0] = W0[j][k]
            modelo.w[1] = W1[j][k]
            ypred = modelo.predict(X9)
            mse = mean_squared_error(y, ypred)
            Erro[j][k] = mse
    return Erro
        

ax = plt.axes(projection="3d")
W0, W1 = np.meshgrid(w0, w1)
Erro = z_function(W0, W1)

ax.plot_wireframe(W0, W1, Erro, alpha=0.5)
ax.plot_surface(W0, W1, Erro, rstride=1, cstride=1, alpha=0.5, cmap='coolwarm', edgecolor='none')

modelo = regressao_linear()
modelo.fit(X9, y)
ypred = modelo.predict(X9)
wh = np.array(modelo.wh)

ax.plot(wh[:,0], wh[:,1], wh[:,2], marker='o', linewidth='0.5', markersize=2)
ax.view_init(azim=0, elev=90)

plt.show()
# Out:
# /Users/otaviolube/Desktop/pos-devai-ifes/int-art-apr-maq/venv/lib/python3.13/site-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /Users/otaviolube/Desktop/pos-devai-ifes/int-art-apr-maq/venv/lib/python3.13/site-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /Users/otaviolube/Desktop/pos-devai-ifes/int-art-apr-maq/venv/lib/python3.13/site-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /Users/otaviolube/Desktop/pos-devai-ifes/int-art-apr-maq/venv/lib/python3.13/site-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /Users/otaviolube/Desktop/pos-devai-ifes/int-art-apr-maq/venv/lib/python3.13/site-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /Users/otaviolube/Desktop/pos-devai-ifes/int-art-apr-maq/venv/lib/python3.13/site-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /Users/otaviolube/Desktop/pos-devai-ifes/int-art-apr-maq/venv/lib/python3.13/site-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /Users/otaviolube/Desktop/pos-devai-ifes/int-art-apr-maq/venv/lib/python3.13/site-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /Users/otaviolube/Desktop/pos-devai-ifes/int-art-apr-maq/venv/lib/python3.13/site-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /Users/otaviolube/Desktop/pos-devai-ifes/int-art-apr-maq/venv/lib/python3.13/site-packages/mpl_toolkits/mplot3d/proj3d.py:150: RuntimeWarning: invalid value encountered in divide
#   txs, tys, tzs = vecw[0] / w, vecw[1] / w, vecw[2] / w

# %% [markdown]
# ## Resumindo, sem o SciKit Learn

# %%
modelo = regressao_linear()
modelo.fit(X9, y)
ypred = modelo.predict(X9)
print(mean_squared_error(y, ypred))
print(modelo.w)
# Out:
# inf
# [[-1.23752389e+236]
#  [-1.84224970e+267]]
# /Users/otaviolube/Desktop/pos-devai-ifes/int-art-apr-maq/venv/lib/python3.13/site-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /Users/otaviolube/Desktop/pos-devai-ifes/int-art-apr-maq/venv/lib/python3.13/site-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /Users/otaviolube/Desktop/pos-devai-ifes/int-art-apr-maq/venv/lib/python3.13/site-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /Users/otaviolube/Desktop/pos-devai-ifes/int-art-apr-maq/venv/lib/python3.13/site-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /Users/otaviolube/Desktop/pos-devai-ifes/int-art-apr-maq/venv/lib/python3.13/site-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /Users/otaviolube/Desktop/pos-devai-ifes/int-art-apr-maq/venv/lib/python3.13/site-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /Users/otaviolube/Desktop/pos-devai-ifes/int-art-apr-maq/venv/lib/python3.13/site-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /Users/otaviolube/Desktop/pos-devai-ifes/int-art-apr-maq/venv/lib/python3.13/site-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /Users/otaviolube/Desktop/pos-devai-ifes/int-art-apr-maq/venv/lib/python3.13/site-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
# /Users/otaviolube/Desktop/pos-devai-ifes/int-art-apr-maq/venv/lib/python3.13/site-packages/sklearn/metrics/_regression.py:570: RuntimeWarning: overflow encountered in square
#   output_errors = _average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)

# %% [markdown]
# ## Usando o SciKit Learn

# %%
from sklearn.linear_model import LinearRegression

modelo = LinearRegression()
modelo.fit(X9, y)
ypred = modelo.predict(X9)
print(mean_squared_error(y, ypred))
print(modelo.intercept_, modelo.coef_)
# Out:
# 5062.380594520542
# 152.13348416289594 [619.22282068]

# %% [markdown]
# ## Modelo Multivariado

# %%
from sklearn.linear_model import LinearRegression

modelo = LinearRegression()
modelo.fit(X, y)
ypred = modelo.predict(X)
print(mean_squared_error(y, ypred))
print(modelo.intercept_, modelo.coef_)
# Out:
# 2859.69634758675
# 152.13348416289597 [ -10.0098663  -239.81564367  519.84592005  324.3846455  -792.17563855
#   476.73902101  101.04326794  177.06323767  751.27369956   67.62669218]
